# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_cleaned = df.dropna()

# %%
print(df_cleaned.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Sex_male       0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
print(df.shape)
# Out:
# (891, 12)

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Survived'] = df['Survived'].astype('category')

# %%
print(df.dtypes)
# Out:
# PassengerId       int64
# Survived       category
# Pclass            int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked         object
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['Age','Fare']] = scaler.fit_transform(df[['Age','Fare']])

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  0.271174
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.472229
# 2                               Heikkinen, Miss. Laina  female  0.321438
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.434531
# 4                             Allen, Mr. William Henry    male  0.434531
# ..                                                 ...     ...       ...
# 886                              Montvila, Rev. Juozas    male  0.334004
# 887                       Graham, Miss. Margaret Edith  female  0.233476
# 888           Johnston, Miss. Catherine Helen "Carrie"  female       NaN
# 889                              Behr, Mr. Karl Howell    male  0.321438
# 890                                Dooley, Mr. Patrick    male  0.396833
#
#      SibSp  Parch            Ticket      Fare Cabin Embarked
# 0        1      0         A/5 21171  0.014151   NaN        S
# 1        1      0          PC 17599  0.139136   C85        C
# 2        0      0  STON/O2. 3101282  0.015469   NaN        S
# 3        1      0            113803  0.103644  C123        S
# 4        0      0            373450  0.015713   NaN        S
# ..     ...    ...               ...       ...   ...      ...
# 886      0      0            211536  0.025374   NaN        S
# 887      0      0            112053  0.058556   B42        S
# 888      1      2        W./C. 6607  0.045771   NaN        S
# 889      0      0            111369  0.058556  C148        C
# 890      0      0            370376  0.015127   NaN        Q
#
# [891 rows x 12 columns]

# %%
df = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.271174      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  0.472229      1
# 2                               Heikkinen, Miss. Laina  0.321438      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.434531      1
# 4                             Allen, Mr. William Henry  0.434531      0
# ..                                                 ...       ...    ...
# 886                              Montvila, Rev. Juozas  0.334004      0
# 887                       Graham, Miss. Margaret Edith  0.233476      0
# 888           Johnston, Miss. Catherine Helen "Carrie"       NaN      1
# 889                              Behr, Mr. Karl Howell  0.321438      0
# 890                                Dooley, Mr. Patrick  0.396833      0
#
#      Parch            Ticket      Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 0        0         A/5 21171  0.014151   NaN      True       False        True
# 1        0          PC 17599  0.139136   C85     False       False       False
# 2        0  STON/O2. 3101282  0.015469   NaN     False       False        True
# 3        0            113803  0.103644  C123     False       False        True
# 4        0            373450  0.015713   NaN      True       False        True
# ..     ...               ...       ...   ...       ...         ...         ...
# 886      0            211536  0.025374   NaN      True       False        True
# 887      0            112053  0.058556   B42     False       False        True
# 888      2        W./C. 6607  0.045771   NaN     False       False        True
# 889      0            111369  0.058556  C148      True       False       False
# 890      0            370376  0.015127   NaN      True        True       False
#
# [891 rows x 13 columns]
